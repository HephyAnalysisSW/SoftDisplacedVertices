# %%
import ROOT

# %%
ROOT.DisableImplicitMT()

# %%
df = ROOT.RDataFrame("Events", "/scratch-cbe/users/alikaan.gueven/ML_KAAN/Ang_GNN_nano_merged/qcdht0100_2018/qcdht0100_2018__merged.root")
df = df.Define("amx_SDVSecVtx_pt", "ArgMax(SDVSecVtx_pt)")
df.Display(["MET_pt", "amx_SDVSecVtx_pt", "SDVSecVtx_pt"], 5, 10).Print()
# Out:
# +-----+----------+------------------+--------------+
# | Row | MET_pt   | amx_SDVSecVtx_pt | SDVSecVtx_pt |
# +-----+----------+------------------+--------------+
# | 0   | 159.925f | 0                | 1.19336f     |
# +-----+----------+------------------+--------------+
# | 1   | 151.903f | 1                | 1.31445f     |
# |     |          |                  | 8.11719f     |
# +-----+----------+------------------+--------------+
# | 2   | 171.535f | 0                | 10.0469f     |
# |     |          |                  | 1.58496f     |
# |     |          |                  | 5.74609f     |
# |     |          |                  | 5.58203f     |
# +-----+----------+------------------+--------------+
# | 3   | 163.633f | 0                | 1.64355f     |
# +-----+----------+------------------+--------------+
# | 4   | 178.755f | 1                | 1.10547f     |
# |     |          |                  | 4.10938f     |
# +-----+----------+------------------+--------------+
